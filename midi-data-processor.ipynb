# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os

for dirname, _, filenames in os.walk('EMOPIA_1.0/midis/'):
    print(dirname, len(filenames))

# %%
# !pip install mido
# !pip install einops

# %%
import mido
from mido import MidiFile
import numpy as np

def write_midi(pr, ticks_per_beat, write_path, tempo=80):
    def pr_to_list(pr):
        # List event = (pitch, velocity, time)
        T, N = pr.shape
        t_last = 0
        pr_tm1 = np.zeros(N)
        list_event = []
        for t in range(T):
            pr_t = pr[t]
            mask = (pr_t != pr_tm1)
            if (mask).any():
                for n in range(N):
                    if mask[n]:
                        pitch = n
                        velocity = int(pr_t[n])
                        # Time is incremented since last event
                        t_event = t - t_last
                        t_last = t
                        list_event.append((pitch, velocity, t_event))
            pr_tm1 = pr_t
        return list_event
    # Tempo
    microseconds_per_beat = mido.bpm2tempo(tempo)
    # Write a pianoroll in a midi file
    mid = MidiFile()
    mid.ticks_per_beat = ticks_per_beat

    # Each instrument is a track
    for instrument_name, matrix in pr.items():
        # Add a new track with the instrument name to the midi file
        track = mid.add_track(instrument_name)
        # transform the matrix in a list of (pitch, velocity, time)
        events = pr_to_list(matrix)
        # Tempo
        track.append(mido.MetaMessage('set_tempo', tempo=microseconds_per_beat))
        # Add the program_change
        try:
            program = program_change_mapping[instrument_name]
        except:
            # Defaul is piano
            # print instrument_name + " not in the program_change mapping"
            # print "Default value is 1 (piano)"
            # print "Check acidano/data_processing/utils/program_change_mapping.py"
            program = 1
        track.append(mido.Message('program_change', program=program))

        # This list is required to shut down
        # notes that are on, intensity modified, then off only 1 time
        # Example :
        # (60,20,0)
        # (60,40,10)
        # (60,0,15)
        notes_on_list = []
        # Write events in the midi file
        for event in events:
            pitch, velocity, time = event
            if velocity == 0:
                # Get the channel
                track.append(mido.Message('note_off', note=pitch, velocity=0, time=time))
                notes_on_list.remove(pitch)
            else:
                if pitch in notes_on_list:
                    track.append(mido.Message('note_off', note=pitch, velocity=0, time=time))
                    notes_on_list.remove(pitch)
                    time = 0
                track.append(mido.Message('note_on', note=pitch, velocity=velocity, time=time))
                notes_on_list.append(pitch)
    mid.save(write_path)
    return

#!/usr/bin/env python
# -*- coding: utf8 -*-

# from mido import MidiFile
from unidecode import unidecode
# import numpy as np

#######
# Pianorolls dims are  :   TIME  *  PITCH


class Read_midi(object):
    def __init__(self, song_path, quantization):
        ## Metadata
        self.__song_path = song_path
        self.__quantization = quantization

        ## Pianoroll
        self.__T_pr = None

        ## Private misc
        self.__num_ticks = None
        self.__T_file = None

    @property
    def quantization(self):
        return self.__quantization

    @property
    def T_pr(self):
        return self.__T_pr

    @property
    def T_file(self):
        return self.__T_file

    def get_total_num_tick(self):
        # Midi length should be written in a meta message at the beginning of the file,
        # but in many cases, lazy motherfuckers didn't write it...

        # Read a midi file and return a dictionnary {track_name : pianoroll}
        mid = MidiFile(self.__song_path)

        # Parse track by track
        num_ticks = 0
        for i, track in enumerate(mid.tracks):
            tick_counter = 0
            for message in track:
                # Note on
                time = float(message.time)
                tick_counter += time
            num_ticks = max(num_ticks, tick_counter)
        self.__num_ticks = num_ticks

    def get_pitch_range(self):
        mid = MidiFile(self.__song_path)
        min_pitch = 200
        max_pitch = 0
        for i, track in enumerate(mid.tracks):
            for message in track:
                if message.type in ['note_on', 'note_off']:
                    pitch = message.note
                    if pitch > max_pitch:
                        max_pitch = pitch
                    if pitch < min_pitch:
                        min_pitch = pitch
        return min_pitch, max_pitch

    def get_time_file(self):
        # Get the time dimension for a pianoroll given a certain quantization
        mid = MidiFile(self.__song_path)
        # Tick per beat
        ticks_per_beat = mid.ticks_per_beat
        # Total number of ticks
        self.get_total_num_tick()
        # Dimensions of the pianoroll for each track
        self.__T_file = int((self.__num_ticks / ticks_per_beat) * self.__quantization)
        return self.__T_file

    def read_file(self):
        # Read the midi file and return a dictionnary {track_name : pianoroll}
        mid = MidiFile(self.__song_path)
        # Tick per beat
        ticks_per_beat = mid.ticks_per_beat

        # Get total time
        self.get_time_file()
        T_pr = self.__T_file
        # Pitch dimension
        N_pr = 128
        pianoroll = {}

        def add_note_to_pr(note_off, notes_on, pr):
            pitch_off, _, time_off = note_off
            # Note off : search for the note in the list of note on,
            # get the start and end time
            # write it in th pr
            match_list = [(ind, item) for (ind, item) in enumerate(notes_on) if item[0] == pitch_off]
            if len(match_list) == 0:
                print("Try to note off a note that has never been turned on")
                # Do nothing
                return

            # Add note to the pr
            pitch, velocity, time_on = match_list[0][1]
            pr[time_on:time_off, pitch] = velocity
            # Remove the note from notes_on
            ind_match = match_list[0][0]
            del notes_on[ind_match]
            return

        # Parse track by track
        counter_unnamed_track = 0
        for i, track in enumerate(mid.tracks):
            # Instanciate the pianoroll
            pr = np.zeros([T_pr, N_pr])
            time_counter = 0
            notes_on = []
            for message in track:

                ##########################################
                ##########################################
                ##########################################
                # TODO : keep track of tempo information
                # import re
                # if re.search("tempo", message.type):
                #     import pdb; pdb.set_trace()
                ##########################################
                ##########################################
                ##########################################


                # print message
                # Time. Must be incremented, whether it is a note on/off or not
                time = float(message.time)
                time_counter += time / ticks_per_beat * self.__quantization
                # Time in pr (mapping)
                time_pr = int(round(time_counter))
                # Note on
                if message.type == 'note_on':
                    # Get pitch
                    pitch = message.note
                    # Get velocity
                    velocity = message.velocity
                    if velocity > 0:
                        notes_on.append((pitch, velocity, time_pr))
                    elif velocity == 0:
                        add_note_to_pr((pitch, velocity, time_pr), notes_on, pr)
                # Note off
                elif message.type == 'note_off':
                    pitch = message.note
                    velocity = message.velocity
                    add_note_to_pr((pitch, velocity, time_pr), notes_on, pr)

            # We deal with discrete values ranged between 0 and 127
            #     -> convert to int
            pr = pr.astype(np.int16)
            if np.sum(np.sum(pr)) > 0:
                name = unidecode(track.name)
                name = name.rstrip('\x00')
                if name == u'':
                    name = 'unnamed' + str(counter_unnamed_track)
                    counter_unnamed_track += 1
                if name in pianoroll.keys():
                    # Take max of the to pianorolls
                    pianoroll[name] = np.maximum(pr, pianoroll[name])
                else:
                    pianoroll[name] = pr
        return pianoroll



def get_pianoroll_time(pianoroll):
    T_pr_list = []
    for k, v in pianoroll.items():
        T_pr_list.append(v.shape[0])
    if not len(set(T_pr_list)) == 1:
        print("Inconsistent dimensions in the new PR")
        return None
    return T_pr_list[0]

def get_pitch_dim(pianoroll):
    N_pr_list = []
    for k, v in pianoroll.items():
        N_pr_list.append(v.shape[1])
    if not len(set(N_pr_list)) == 1:
        print("Inconsistent dimensions in the new PR")
        raise NameError("Pr dimension")
    return N_pr_list[0]

def dict_to_matrix_old(pianoroll):
    T_pr = get_pianoroll_time(pianoroll)
    N_pr = get_pitch_dim(pianoroll)
    rp = np.zeros((T_pr, N_pr), dtype=np.int16)
    for k, v in pianoroll.items():
        if rp.sum() < v.sum():
            rp = v
    return rp

## MULTI CHANNEL
def dict_to_matrix(pianoroll):
    T_pr = get_pianoroll_time(pianoroll)
    N_pr = get_pitch_dim(pianoroll)
    all_m = []
    for k, v in pianoroll.items():
        rp = np.zeros((T_pr, N_pr), dtype=np.int16)
        all_m.append(np.maximum(rp, v))
        
    all_m = sorted(all_m, reverse=True, key=lambda x: x.sum())
    
    return all_m[:2]

# %%
import random
import pandas as pd
import imageio
import numpy as np
from argparse import ArgumentParser

from tqdm.auto import tqdm
import matplotlib.pyplot as plt

import einops
import torch
import torch.nn as nn
from torch.optim import Adam
from torch.utils.data import DataLoader, TensorDataset

print("GPU -->", torch.cuda.is_available())
# Out:
# GPU --> True

# %%
ARTIST_DIR = 'LakhMIDI/'

import os

audio_data_arr = []
audio_tags_arr = []
audio_artist_arr = []

songs_to_be_extracted = 1555
genre_to_be_extracted = "blues" # 'ALL' # 'disco' # 'trance' # 'jazz'
disable_genre = False


df = pd.read_csv(r'artists_filtered.csv')

for dirname, _, filenames in os.walk(ARTIST_DIR):
    artist = dirname.split('LakhMIDI/')[1].replace('_', ' ')
    
    entry = df[df['artist_mb'].str.contains(artist) == True]
    
    if len(entry) !=  1:
        continue
    
    print(artist)

    tags = entry.iloc[0]['tags_mb']
    if pd.isna(tags):
        tags = entry.iloc[0]['tags_lastfm']
    if pd.isna(tags):
        continue
        
    tags = [a.strip().replace('-', ' ').replace('&', ' ').lower() for a in tags.split(';')]
    
    if not disable_genre and genre_to_be_extracted not in tags and genre_to_be_extracted != 'ALL':
        continue
    if disable_genre:
        print('Not Checking Genre')
    
    for filename in filenames:
        if len(audio_data_arr) > songs_to_be_extracted:
            break
        try:
            if '.mid' in filename:
                filepath = os.path.join(dirname, filename)
                
                audio_dict = Read_midi(filepath, 4).read_file()
                audio_matrix = dict_to_matrix(audio_dict)
                
                if len(audio_matrix) < 2:
                    continue
                
                audio_data_arr.append(audio_matrix)
                audio_tags_arr.append(tags)
                audio_artist_arr.append(artist)
                
                print('-->',len(audio_data_arr),'<--', len(audio_matrix), end="\r")
#                 print('-->',len(audio_data_arr),'<--', end="\r")
        except Exception as err:
            print("ERROR", err)
            pass

print('')

print(len(audio_data_arr))
print(len(audio_tags_arr))
print(len(audio_artist_arr))
# audio_data_arr1 = audio_data_arr
# Out:
# Rick Derringer
# Jimmy Barnes
# Lois Lane
# Duran Duran
# Ludwig van Beethoven
# Gene Pitney
# The Happenings
# Glenn Frey
# Tag Team
# Ed Townsend
# The Offspring
# Helen Reddy
# Herbie Hancock
# Joe Diffie
# En Vogue
# Sergio
# Gerry Mulligan Quartet
# Wang Chung
# Hughie Cannon
# MFSB
# Barclay James Harvest
# Joan Osborne
# Baltimora
# Ekseption
# Andrea Bocelli
# De Deurzakkers
# Mariah Carey
# Matia Bazar
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# The Manhattan Transfer
# Thomas Campion
# Ann Farina
# Creed
# Nada Surf
# EMF
# Banda Blanca
# Peter Frampton
# Ronny Jordan
# Status Quo
# Fairport Convention
# Stanley Clarke
# Kim Carnes
# Reeves
# Alice Cooper
# Procol Harum
# New Order
# Barenaked Ladies
# Isaac Hayes
# Roy Orbison
# Spandau Ballet
# Mr. Mister
# Little Tony
# Revere
# Massada
# Melissa Manchester
# El DeBarge
# Desireless
# Norman Connors
# Confederate Railroad
# Ronnie Spector
# Robert Hampton
# Julian Lennon
# Spice Girls
# Albert West
# Hues Corporation
# Esther Phillips
# Mathis
# Al Martino
# Megadeth
# Melissa Etheridge
# Shania Twain
# Luther Vandross
# Daniel Boone
# Hans Albers
# Paoli
# The Outfield
# Third Eye Blind
# Patrick Swayze
# Mark Morrison
# Demis Roussos
# David Gates
# Camaleonti
# The Outhere Brothers
# Phil Collins
# The Buckinghams
# Willie Nelson
# Michel Delpech
# Jeannie C. Riley
# Fatboy Slim
# Macy Gray
# Juan Luis Guerra
# Atlanta Rhythm Section
# Tommy Edwards
# Suzanne Vega
# Norman Greenbaum
# The Robert Cray Band
# Jovanotti
# Lavinia Jones
# Nashville Teens
# Tears for Fears
# Aerosmith
# New Kids on the Block
# Ottawan
# Percy Sledge
# Amedeo Minghi
# Carey
# Rob Zombie
# Wet Willie
# Wet Wet Wet
# Bobby Rydell
# Jamaaladeen Tacuma
# Gino Vannelli
# Mezzoforte
# Gabber Piet
# Del Shannon
# Information Society
# Burt Bacharach
# Coolio
# Martha Reeves
# Wild Cherry
# Peter Cetera
# Cole Porter
# Boz Scaggs
# Goo Goo Dolls
# Ram Jam
# Doe Maar
# Paul de Leeuw
# Joni Mitchell
# Corey Hart
# La Bionda
# Busta Rhymes
# Little River Band
# Luther Ingram
# The Presidents of the United States of America
# Toad the Wet Sprocket
# The New Colony Six
# Sam Cooke
# Rory Block
# Guns N Roses
# The Weather Girls
# Ace of Base
# The Human League
# Johnny Hoes
# Vicki Sue Robinson
# Rose Royce
# Elvis Costello
# NOFX
# 2 the Core
# TLC
# Zebrahead
# Paul Mauriat
# Joey Dee
# Hue and Cry
# Canned Heat
# The Beautiful South
# The Knack
# Bommbastic
# Eurythmics
# MC Hammer
# Frank Sinatra
# Johannes Brahms
# Romantics
# Ana Caram
# The Fixx
# Vanessa Williams
# Alberto Fortis
# Bill Haley
# Matthew Wilder
# Donna Hightower
# Semisonic
# Billy Ray Cyrus
# Lee Ritenour
# Shawn Mullins
# Kaoma
# Glenn Medeiros
# Boney M.
# Jeff Beck
# Gregori
# Rickie Lee Jones
# Paul Dukas
# Jessica Simpson
# Tower of Power
# McCartney
# Savage Garden
# A Taste of Honey
# Annie Cordy2
# Jamiroquai
# John Paul Young
# The Romantics
# Eve 6
# Natalie Imbruglia
# Kris Kristofferson
# Searchers
# Bill Haley and His Comets
# Leo Sayer
# Jimmy Nail
# Supertramp
# Kraftwerk
# Johann Nepomuk Hummel
# Chesney Hawkes
# Jane Child
# Counting Crows
# Peppino di Capri
# The Brecker Brothers
# Joan Jett
# Alan Jackson
# Guesch Patti
# Blackstreet
# Robert Leroy
# Marc Cohn
# Vanilla Fudge
# The Cranberries
# Ry Cooder
# Patrick Hernandez
# Jimmy Reed
# Daft Punk
# Lynyrd Skynyrd
# Jackson Browne
# Chip Davis
# Collective Soul
# The Doobie Brothers
# Men Without Hats
# Village People
# Annie Lennox
# Alberti
# Nick MacKenzie
# Derek and the Dominos
# Tommy Flanagan
# Paula Abdul
# Talking Heads
# Culture Club
# Ray Parker Jr.
# Merle Travis
# Metallica
# Johnny Kemp
# The Style Council
# Marillion
# CB Milton
# Bob Seger
# Everclear
# Vince Guaraldi
# Trio Rio
# Fay Lovsky
# VOF de Kunst
# Grateful Dead
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Johnny Mercer
# E-Rotic
# Veruca Salt
# Ace Frehley
# Peter Gabriel
# Another Level
# Steve Vai
# Bobby Prins
# Bette Midler
# Brownsville Station
# John Lee Hooker
# Gibson Brothers
# Carmen
# Crystal Waters
# The Kelly Family
# Henry Butler
# Jimmy Ruffin
# Morris Albert
# Henry Arland
# Technohead
# Tracy Byrd
# Rascel
# Herbie Mann
# Alain Souchon
# Xscape
# Irene Cara
# Julio Iglesias
# Nick Kamen
# Dr. Hook
# The Kinks
# Harry Nilsson
# Jeffrey Reid Baker
# Thomas Dolby
# Radiohead
# Leif Garrett
# The Box Tops
# Leo Friedman
# Joshua Kadison
# Michael Sembello
# Elliot
# Trinere
# Ozzy Osbourne
# Curtis Mayfield
# American Made
# Survivor
# Conway Twitty
# The Mindbenders
# Cosmix
# Trini Lopez
# The McGuire Sisters
# The Boomtown Rats
# Blind Guardian
# Babylon Zoo
# Ray Davies
# Chris Norman
# Bruce Channel
# Amanda McBroom
# 2Boys
# Ernst Neger
# Mac Davis
# Bruce Hornsby
# Dan Fogelberg
# Jimmy Gilmer
# Geri Halliwell
# The Dinky Toys
# Loverboy
# Dixie Chicks
# Gary Lewis
# Edwyn Collins
# MN8
# Wilbert Harrison
# The Pasadenas
# Bobby Vinton
# Our Lady Peace
# Huey Lewis
# Alpert
# Michael English
# 2 Unlimited
# The Christians
# Centory
# Cilla Black
# Donna Summer
# Firefall
# White Zombie
# Barry Manilow
# The Marcels
# Pet Shop Boys
# Captain Jack
# Squirrel Nut Zippers
# Jimmy McGriff
# The Hooters
# Roberta Flack
# Steppenwolf
# Bryan Adams
# Alexander Peter
# Pseudo Echo
# Paul Young
# Daniel
# Berlin
# The Honeydrippers
# Godspell
# Carpenter
# Bobby Vee
# The J. Geils Band
# 311
# Cheryl Ladd
# The Four Aces
# Save Ferris
# Jett
# Will Glahe
# BZN
# Maria Muldaur
# The Cowsills
# Tommy Roe
# Travis Tritt
# The Verve Pipe
# Bill Medley
# Gaskin Street
# Chumbawamba
# They Might Be Giants
# Nancy Sinatra
# Talk Talk
# Howard Jones
# Crash Test Dummies
# Haddaway
# Orchestral Manoeuvres in the Dark
# Dik Dik
# Limahl
# Lisa Lisa
# Lindsey Buckingham
# Billy Mayerl
# Randy VanWarmer
# Sarah McLachlan
# Freddy Cannon
# Us3
# Koos Alberts
# Jimmy Somerville
# Dan Hartman
# Bob Marley
# Rocky Horror
# Elvin Bishop
# Perry Como 2
# David Byrne
# Toussaint
# Raydio
# Anthony Richard
# The Folk Implosion
# Los Lobos
# ERROR Could not decode key with 2 flats and mode 255
# Dennie Christian
# Sam The Sham
# Mo-Do
# George Michael
# Peter Cornelius
# Lou Reed
# The Ronettes
# Deacon Blue
# Bernhard Brink
# Anita Ward
# Love Unlimited Orchestra
# B.G. The Prince of Rap
# Michael Penn
# The Brothers Four
# Middle of the Road
# Jaggerz
# Richard Sanderson
# Joe Dassin
# Albert Hammond
# Al Hirt
# Shola Ama
# Showaddywaddy
# The New Seekers
# Peter Tosh
# Sandy Denny
# Tal Bachman
# Gipsy Kings
# Far Corporation
# The Supremes
# Trio Hellenique
# The Beach Boys
# Toni Braxton
# Bob Carlisle
# Dire Straits
# Sheryl Crow
# Energy 52
# Gordon
# Classics IV
# Five Man Electrical Band
# Wolter Kroes
# Level 42
# Curtis Stigers
# Al Green
# Charles Aznavour
# Paul McCartney
# Lipps, Inc.
# Peter de Koning
# Gwen McCrae
# Deep Blue Something
# The Notorious B.I.G.
# Take That
# Carl Douglas
# Linkin Park
# Kristina Bach
# Carl Teike
# Sheena Easton
# Jesus Jones
# Lesley Gore
# Ricchi e Poveri
# Bauer
# Chuck Mangione
# The Spencer Davis Group
# The Flying Pickets
# Rare Earth
# Whigfield
# Jennifer Lopez
# Wilson Pickett
# Starland Vocal Band
# Marusha
# Faith No More
# Time Bandits
# Bill Withers
# Sonic Youth
# La Bouche
# Randy Newman
# Jim Croce
# Bad English
# Carmina Burana
# Andy Kim
# Randy Crawford
# George Frideric Handel
# Renato Teixeira
# Wolfgang Ambros
# Burton Lane
# Yvonne Elliman
# Billie Myers
# White Town
# Pat Benatar
# Het Goede Doel
# Shakatak
# Nina Simone
# Major Harris
# Jerome Kern
# Alain Bashung
# Fleetwood Mac
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Spin Doctors
# Jimmy Cliff
# Golden Earring
# Leon Russell
# Quiet Riot
# Tommy James
# C.J. Lewis
# Nini Rosso
# Little Texas
# Lutricia McNeal
# Bananarama
# Amy Grant
# Ringo Starr
# Scatman John
# Charlie Rich
# B.W. Stevenson
# Commander Cody
# Paul Anka
# The Platters
# Sister Sledge
# J.J. Jackson
# McDonald
# Curtis Lee
# Liesbeth List
# Silverchair
# Tool
# Billy Idol
# Articolo 31
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# The Left Banke
# Dobie Gray
# Sailor
# Kylie Minogue
# Tozzi
# Johnny and The Hurricanes
# Aretha Franklin
# John Lennon
# Dr. Alban
# Howard Carpendale
# Mocedades
# Bay City Rollers
# Atlantic Starr
# Fluitsma
# Digno Garcia
# The Tony Rich Project
# Brian McKnight
# Erroll Garner
# Steps Ahead
# Chris Isaak
# Jackie McLean
# Huub Hangop
# Eddie Floyd
# Bush
# Blues Traveler
# Kenny Loggins
# Michael McDonald
# Steve Perry
# Stiltskin
# Belinda Carlisle
# Crests
# Frank Mills
# Electric Light Orchestra
# Smash Mouth
# Frankie Avalon
# Peter Allen
# Alannah Myles
# Axelle Red
# Steve Winwood
# Freda Payne
# Alpenrebellen
# Toni Basil
# The Five Satins
# Desmond Dekker
# Au bonheur des dames
# John Denver
# Dance 2 Trance
# Gompie
# Ann Peebles
# Diana Ross
# Rionegro
# Marvin Hamlisch
# The Clash
# Junior Walker
# The Hollies
# Gary Glitter
# Christopher Cross
# Michael Bolton
# Sugarloaf
# Milli Vanilli
# Kalua Beach Boys
# Crowded House
# Mitch Ryder
# Dusty Springfield
# The Marshall Tucker Band
# The Archies
# Rush
# Alpentrio Tirol
# Tasmin Archer
# Clouseau
# Jive Bunny
# Godsmack
# Janet Jackson
# Don Backy
# Laid Back
# Julie Covington
# Jann Arden
# Feargal Sharkey
# Fourplay
# Fats Domino
# Dalla
# Robert Knight
# The Rivieras
# Vanessa Paradis
# Typically Tropical
# Soft Cell
# Uriah Heep
# Cock Robin
# Gebroeders Grimm
# The Walker Brothers
# Donny Osmond
# Average White Band
# Miles John
# The Pretenders
# Jackie Wilson
# Bombalurina
# The Spotnicks
# BBMak
# The Allman Brothers Band
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Amii Stewart2
# Sixpence None the Richer
# Communards
# Maria McKee
# Player
# Gerard Joling
# Alvin Stardust
# Christina Aguilera
# Sophie B. Hawkins
# The Surfaris
# Zez Confrey
# The Youngbloods
# DJ BoBo
# Freddie Jackson
# Claude Debussy
# Free
# Wendy Moten
# Robert Palmer
# Miller
# Snoop Dogg
# Billy Fury
# Gatto Panceri
# Love Sculpture
# DJ Quicksilver
# Ben E. King
# OMC
# Paula Cole
# The Syndicate of Sound
# Francesco De Gregori
# Bruce Springsteen
# Hot Chocolate
# Color Me Badd
# The Dave Clark Five
# Jean Knight
# The Searchers
# The Rolling Stones
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# ERROR 5 <-- 2
# Carole King 2
# The Ritchie Family
# Sailor Moon
# Warren Zevon
# Jaco Pastorius
# Big Bad Voodoo Daddy
# Fontella Bass
# Roxy Music
# Robin Beck
# Urban Cookie Collective
# Dingetje
# Shirley Bassey
# Mark Collie
# Billy Preston
# Adriano Celentano
# KWS
# Anita Meyer
# Jimi Hendrix
# Motels
# Percy Faith
# Gino Paoli
# Rod Stewart
# The Bluegrass Cardinals
# Jethro Tull
# ZZ Top
# The Gap Band2
# The Four Seasons
# Blue System
# Jody Reynolds
# Joe Dolce
# Zucchero
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Equipe 84-- 2
# Vanilla Ice
# East 17
# Mark Oh
# Mel Carter
# Bob Dylan
# No Doubt<-- 2
# The Charmaines
# Nick Berry
# Chic
# Danilo Amerio
# Alliage
# Fugees
# The Stylistics
# Aswad
# Foo Fighters
# Carl Perkins
# Apollo 100
# Frankie Valli
# Frank Galan
# Frans Bauer
# De Nachroave
# Red Hot Chili Peppers
# Don Henley
# Quick Pick
# The Pointer Sisters
# Joe South
# Fat Boys
# Aaliyah
# Tony Orlando
# Special EFX
# Patti Smith
# Erasure
# Dexys Midnight Runners
# T. Rex
# Imca Marina
# The Lemonheads
# Mark Snow
# The Commitments
# Marc Almond
# Renzo Arbore
# Alphaville- 2
# Missy Elliott
# John Mellencamp
# Jackie DeShannon
# Dirotta su Cuba
# Sammy Nestico
# Nicki French
# Terry Stafford
# E.Z.K
# Anne Murray
# Michael Zager
# The Stranglers
# Eminem
# George McCrae
# Jon Cleary
# Jerry Lee Lewis
# Rocco Granata
# BAP
# Byron Berline
# Suzi Quatro
# Johnny Shines
# Patricia Paay
# John Fogerty
# Drupi76 <-- 2
# Vertical Horizon
# Amie Comeaux
# Neil Diamond
# Edison Lighthouse
# Nico Landers
# Jefferson Airplane
# Allan Theo
# Mink DeVille
# Andrew Lloyd Webber
# Trance
# The Zombies
# Pato Banton
# Antonio Carlos
# Floyd Cramer
# The Sylvers
# Jason Donovan
# Diana King
# Jeffrey Osborne
# The Corrs
# Angelo Branduardi
# Whitesnake
# Emmanuel Chabrier
# Fifth Dimension
# Freak Power
# The Mighty Mighty Bosstones
# Debby Boone
# Georgie Fame
# Le Grand Orchestre du Splendid
# Acoustic Alchemy
# Dolls United2
# Johnny Hates Jazz
# Rufus Thomas
# Santa Esmeralda
# Corry Konings
# Ryan Paris
# Mike Reno
# Chris Andrews
# Lena Horne
# Christoph Willibald Gluck
# Barry White
# Marvin Gaye
# Les Humphries Singers
# Barry John
# 10,000 Maniacs
# Swing Out Sister
# Gene Vincent
# Bert Heerink
# Mel C
# Midnight Oil
# The Chiffons
# The Grass Roots
# Harold Melvin
# Naked Eyes
# Rene Carol
# Reel 2 Real
# William Orbit
# Bellamy Brothers
# Xavier Cugat
# Vera
# Walter Donaldson
# Palemiger Spatzen
# Janis Ian
# Rage Against the Machine
# Assekruus
# Candi Staton
# The KLF
# Tupac
# Haley
# Texas
# Tom Petty
# Quatro
# Peter Schilling
# Marilyn Manson
# Edgar Winter
# Wolfgang Amadeus Mozart
# Tom Turpin
# Shawn Colvin
# Divinyls
# Charles-Valentin Alkan
# Sugar Lee Hooper
# Go West
# The Cure
# The Beau Brummels
# Buddy Holly
# Chip Taylor
# Al Wilson
# Darude
# Beres Hammond
# Billie Jo Spears
# B.B. King
# Stray Cats- 2
# Gary Moore
# Michael Stanley Band
# Nine Days
# Grand Funk Railroad
# Shaun Cassidy
# John Farnham
# The Blue Diamonds
# Eddy Grant
# Ohio Express
# The Four Preps
# The Animals
# Rozalla
# Thin Lizzy
# Dave Mason
# Red 5
# Jars of Clay
# Harvey Danger
# The Cover Girls
# Wham
# David Lee Roth
# Al Stewart
# Renee Rosnes
# Champaign
# 2 Brothers on the 4th Floor
# Sauter-Finegan Orchestra
# The Partridge Family
# Bob Welch
# Nakatomi
# Vicki Brown
# Stevie Nicks
# Chuck Berry
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Zhi-Vago<-- 2
# Dion
# Otis Redding
# Battiato<-- 2
# Soul II Soul
# Oingo Boingo
# Lou Bega
# Freek de Jonge
# Tracey Ullman
# Harry Chapin
# Quarterflash
# Gladys Knight
# The Rutles
# Twila Paris
# Simon and Garfunkel
# Izabella
# Anggun
# Robert Miles
# Willeke Alberti
# The Righteous Brothers
# Claudia Schmidt
# Don McLean
# Ernie K-Doe
# Leonard Bernstein
# Pater Moeskroen
# Antonello Venditti
# Art of Noise
# Harold Faltermeyer
# Rudi Carrell
# Mary J. Blige
# Boney James
# Westernhagen
# Jody Watley
# Small Faces
# Bobby Goldsboro
# Rednex
# Ben Folds Five
# Percy Grainger
# New Vaudeville Band
# Gin Blossoms
# Tanita Tikaram
# The Alan Parsons Project
# Fun Factory
# Roy Clark
# Elkie Brooks
# Barry Mann
# The Escape Club
# Alunni del Sole
# Alanis Morissette
# The Rippingtons
# M2M
# DJ Jazzy Jeff
# The Mavericks
# The Main Ingredient
# U96
# Blues Image
# Londonbeat- 2
# Dave Grusin
# Taja Sevelle
# Alien Ant Farm
# Alain Chamfort
# Meredith Brooks
# Michael Learns to Rock
# Gloria Gaynor
# Robbie Williams
# Joey Ramone
# Thelma Houston
# Green Day
# The Smashing Pumpkins
# Bobby Bloom
# dc Talk
# The Contours
# Three Dog Night
# Simple Minds
# De Havenzangers
# Lynn Anderson
# Ben Cramer
# Maxi Priest
# REO Speedwagon
# Bart Herman
# Scott James
# Michele Zarrillo
# Walter Egan
# Jantje Koopmans
# Atomic Kitten
# George Harrison
# Gordon Lightfoot
# Technotronic
# David Essex
# Janis Joplin
# East Side Beat
# Smokey Robinson
# Sergio Franchi
# Peter Maffay
# a-ha
# INXS
# Chaka Khan
# Prince Ital Joe
# Jerry Herman
# Celentano
# OMD
# Cats
# Black Rob
# Todd Rundgren
# Gary Fane
# The Trammps
# The Cardigans
# Def Leppard
# Laura Branigan
# Meat Puppets
# Raf
# Vera Lynn
# Julie Andrews
# Niamh Kavanagh
# Laura Pausini
# Beastie Boys
# The Chordettes
# Air Supply
# Stevie Wonder
# Blattschuss
# Boy George
# Natalie Cole
# Oleta Adams
# Tony Joe White
# Fairground Attraction
# Heart
# Drafi Deutscher
# Debbie Gibson
# Kim Wilde
# Gala
# Scatman
# Creedence Clearwater Revival
# Booming Support
# Young Paul
# Michael Damian
# Warren
# Masterboy
# Glen Campbell
# Vega
# Terry Jacks
# Gerard Cox
# Dina Carroll
# The Soul Survivors
# Buena Vista Social Club
# Mason Williams
# King Harvest2
# Tori Amos
# Buggles
# Nik Kershaw
# Jon Secada
# Lou Rawls
# Weezer
# Bobby Darin
# Sandie Shaw
# The Ramsey Lewis Trio
# Blind Melon
# Marcy Playground
# Gary Wright
# Soulful Dynamics
# Monty Python
# Diamond Jim
# Groove Theory
# Roy Black
# Little Eva
# Murray Head
# Kiki Dee
# Joseph Kosma
# Brotherhood of Man
# Umberto Tozzi
# Johnny Logan
# DJ Paul Elstak
# The Lemon Pipers
# Rupert Holmes
# Fastball
# Faith Evans
# Steve Miller Band
# Charlie Makes The Cook
# The Isley Brothers
# Lenny Kravitz
# Trisha Yearwood
# Fiorella Mannoia
# The Rubettes
# Crosby Bing
# Marilyn Monroe
# Freddie Mercury
# The Everly Brothers
# The Troggs
# Judy Collins
# Al Jarreau
# The Swinging Blue Jeans
# Johnny Horton
# Modern Talking
# Deniece Williams
# LaTour
# Judas Priest
# Army of Lovers
# Lionel Richie
# The Prodigy
# Lisa Stansfield
# Sheb Wooley
# The Bangles
# Ten Years After
# /tmp/ipykernel_30734/4054822731.py:20: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   entry = df[df['artist_mb'].str.contains(artist) == True]
# Norman Blake
# George Baker Selection
# Allan Sherman
# Skee-Lo
# The Bluebells
# Rick James
# Ohio Players
# Fiona Apple
# Alma Cogan
# Luniz
# Stephen Bishop
# Dave Matthews Band
# Vengaboys
# King Crimson
# Nine Inch Nails
# Soundgarden
# Eddie Cochran
# Johnny Mathis
# The Standells
# Tom Astor
# Reel Big Fish
# Jackson 5
# Imperial Teen
# Whitney Houston
# Los Bravos
# Chyp-notic
# Frankie Goes to Hollywood
# Puff Daddy
# Telly Savalas
# Chris Montez
# Isabelle Adjani
# Eric Clapton
# ERROR data byte must be in range 0..127
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# ...
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Sawyer Brown2
# Bonnie Raitt
# Kate Bush
# Miami Sound Machine
# FIXX
# Britney Spears
# Ronan Keating
# Jodeci
# Carly Simon
# Al Jolson
# Bronski Beat
# Die Fantastischen Vier
# Gary Puckett
# Yazoo
# Mary Wells
# Eric Carmen
# Van McCoy
# Johnny Bristol
# Weather Report
# Billy Paul
# Restless Heart
# Boys Town Gang
# UZEB
# Stone Temple Pilots
# Skid Row
# Taylor James
# The Shamen
# The Ink Spots
# Supermax
# Eddie Kendricks
# Perplexer
# Lobo
# Classics<-- 2
# Die Doofen
# Cliff Richard
# Korgis
# Patrick Bruel
# Stephanie Mills
# Star Wash
# UB40
# Gene Chandler
# Fine Young Cannibals
# Katrina and the Waves
# Aaron Neville
# Bloodhound Gang
# Jimmy Buffett
# Johnny Rivers
# Astrud Gilberto
# Grace Jones
# Roots Syndicate
# Tim Immers
# Jefferson Starship
# Herb Alpert
# Garth Brooks
# Strawberry Alarm Clock
# Honey Cone
# LL Cool J
# Victoria Williams
# Ted Nugent
# George M. Cohan
# 702
# Allen Toussaint
# Eiffel 65
# Worlds Apart
# Will to Power
# Ice Cube
# Nick Gilder
# Deep Purple
# Traveling Wilburys
# Brian Hyland
# Billy Ocean
# Right Said Fred
# Toys
# Drukwerk
# Rembrandts
# Chris de Burgh
# Scott Joplin
# Crystal Gayle
# 883
# Gerry Rafferty
# Power Tools
# Buzz Clifford
# Hugues Aufray
# Jennifer Warnes
# Eddy Arnold
# Silver Convention
# k.d. lang
# Dream Theater
# Gianni Bella
# Righeira
# The Vapors
# De Dijk
# Kenny Thomas
# Pat Boone
# Ultravox
# Roxette
# Petty
# Scott McKenzie
# Bonnie Tyler
# 10cc
# Captain Hollywood Project
# Michael Walthius
# Joe Cocker
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Elton John- 2
# Boyzone
# Taylor Dayne
# Commodores
# Sydney Youngblood
# RMB
# Freakwater
# Jennifer Rush
# Patsy Cline
# Type O Negative
# Billy Joel
# Night Ranger
# Ocean Colour Scene
# Enrique Iglesias
# Johnny Gill
# Billy Swan
# Klein Orkest
# Backstreet Boys
# Bobby Bare
# Thompson Twins
# Depeche Mode
# Iron Butterfly
# Ricky Nelson
# Petula Clark
# Deftones
# Edsels
# Lisa Loeb
# The Easybeats
# Limp Bizkit
# Neil Sedaka
# Jeremy Jackson
# Bad Manners
# Big Mountain
# Magic Affair
# Men at Work
# Bobby McFerrin
# Marco Borsato
# Gruppo Sportivo
# Johnny Nash
# Crowd
# Tracy Chapman
# Home Grown
# Richard Marx
# Dannii Minogue
# Rufus
# Spyro Gyra
# The Tragically Hip
# Rita Coolidge
# The Chaplin Band
# Cyndi Lauper
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Stampeders- 2
# Mica Paris
# Four Tops
# Connie Francis
# Anita Baker
# DaWN
# Tatyana Ali
# Ugly Kid Joe
# Natalie Merchant
# Tammy Wynette
# Detroit Emeralds
# Sammy Hagar
# 20 Fingers
# Dionne Warwick
# Chaka Demus
# Alice in Chains
# Last
# Meat Loaf
# Real Thing
# Animotion
# Arrested Development
# The Rooftop Singers
# Little Richard
# Papa Roach
# 101 Strings
# Tom McDermott
# Maxime Le Forestier
# Alison Moyet
# ERROR data byte must be in range 0..127
# Cheap Trick
# 4 Non Blondes
# The Seekers
# The Fabulous Thunderbirds
# Scritti Politti
# The Wallflowers
# Cornelius Brothers
# 808 State
# The Byrds
# George Thorogood
# James Last- 2
# Van Morrison
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# Try to note off a note that has never been turned on
# England Dan 2
# Bad Boys Blue
# Biagio Antonacci
# Shelley Fabares
# Rick Springfield
# Caught in the Act
# Inner Circle
# The Yardbirds
# Phyllis Nelson
# Adiemus
# Bad Company
# Wilson Phillips
# Calimeros
# The Manhattans
# Linda Ronstadt
# Atlantic Ocean
# Hans Dulfer
# J.J. Cale
# Eddie Holman2
# Dallara
# Kevin Paige
# The Monkees
# The Tremeloes
# Franky Boy
# Borodin
# The Moody Blues
# Matt Bianco
# Mike Oldfield
# Good Shape
# The Sugarhill Gang
# Louis Moreau Gottschalk
# Joe Walsh
# Greg Kihn
# Edward Kleban
# Culture Beat
# E-Type
# Mahalia Jackson
# Shocking Blue
# The Psychedelic Furs
# Peter Kent
# Suzanne Ciani
# Donovan
# Faithless
# Soul Asylum
# The Brian Setzer Orchestra
# Mandy Moore
# Jule Styne
# Anna Oxa
# Martin Dean
# Westlife
# Simply Red
# Eddie Money
# R. Kelly
# Brenton Wood
# Cutting Crew
# Club Nouveau
# The Cyrkle
# Kid Rock
# Cocker
# Joe Satriani
# Buffalo Springfield
# Lloyd James
# Edvard Grieg
# Kim Appleby
# John Waite
# Gloria Estefan
# Marianne Faithfull
# Kadoc
# Cheryl Lynn
# Ruth Jacott
# Bertie Higgins
# David Dundas
# Sister Hazel
# Paola Turci
# Zhane
# Starship
# Caterina Caselli
# Paul Desmond
# Boyz II Men
# Puckett
# M People
# Chocolate
# LeAnn Rimes
# Rick Astley
# New Radicals
# Mungo Jerry
# Rammstein
# Paul Revere and The Raiders
# Giorgio Moroder
# Carpenters
#
# 516
# 516
# 516

# %%
all_genres = {}

for gs in audio_tags_arr:
    for g in gs:
        if g in all_genres.keys():
            all_genres[g] = all_genres[g]+1
        else:
            all_genres[g] = 0
            
print(all_genres)
# Out:
# {'rock': 4308, 'pop': 3619, 'blues': 734, 'hard rock': 864, 'blues rock': 735, 'jazz fusion': 69, 'christian rock': 13, 'electric blues': 47, 'blues-rock': 42, 'aor': 223, 'rock & roll': 618, 'soul': 963, 'rhythm and blues': 42, 'dutch': 120, 'seen live': 461, 'cover': 9, 'Hip-Hop': 42, 'hip hop': 143, 'rap': 89, 'female vocalists': 291, 'catchy': 4, 'american': 2073, 'hiphop': 17, 'rnb': 366, 'live gezien': 3, 'pur': 3, 'ned': 3, 'Less than 30000': 3, 'electronic': 676, 'synthpop': 562, 'alternative rock': 890, '70s': 399, '80s': 650, '90s': 627, 'dance': 439, 'british': 1749, 'new wave': 475, 'electro': 73, 'uk': 1435, 'pop rock': 3046, 'new romantic': 65, 'english': 1306, '00s': 299, 'classic pop and rock': 3126, 'male vocalists': 372, '10s': 144, 'new romantics': 41, 'classical': 283, 'german': 150, 'german composer': 20, 'production music': 53, 'opera': 59, 'piano': 83, 'pianist': 43, 'composer': 190, 'romantic': 74, 'european': 489, 'symphony': 19, 'concerto': 14, 'lo spirito': 14, 'reader s': 14, '32 sonatas': 14, 'opus 57': 14, 'masterworks': 14, 'klavierwerke': 14, 'piano concerto no. 5': 14, 'alicia de larrocha': 14, 'ballad': 3, 'death by heart disease': 3, 'oldies': 387, '60s': 336, 'sunshine pop': 159, 'classic rock': 485, 'soft rock': 899, 'funk': 277, 'All': 191, 'Need to Rate': 18, 'punk': 229, 'punk rock': 168, 'post-punk': 229, 'ska punk': 156, 'usa': 744, 'alternative': 383, 'pop punk': 135, 'skate punk': 30, 'california': 275, 'orange county': 25, 'rock and indie': 750, 'epitaph': 25, 'classic pop punk': 127, 'california punk': 127, 'classic punk': 127, 'orange county punk': 25, '90s punk': 25, '80s punk': 25, 'australian': 94, 'jazz': 450, 'fusion': 6, 'jazz funk': 30, 'post-bop': 2, 'hard bop': 5, 'modal jazz': 2, 'jazz-funk': 47, 'post bop': 2, 'soul jazz': 15, 'jazz and blues': 33, 'academy award winner': 6, 'country': 497, 'funk rock': 79, 'pop rap': 51, 'new jack swing': 133, 'hip hop rnb and dance hall': 91, 'contemporary r&b': 426, 'east coast hip hop': 34, 'death by brain cancer': 3, 'multiple countries': 3, 'dance-pop': 716, 'Disco': 136, 'philly soul': 25, 'Philadelphia': 5, 'Philly': 0, 'instrumental': 64, 'disco funk': 1, 'chill': 13, 'USA': 85, 'motown': 33, 'House': 51, 'groove': 25, 'r&b': 170, 'Pennsylvania': 4, 'discotheque': 6, 'classic soul': 0, 'philly sound': 2, 'MFSB': 0, 'chillout': 51, 'new york': 12, 'experimental': 74, 'sexy': 24, 'downtempo': 56, 'singer-songwriter': 436, 'easy listening': 184, 'Smooth Soul': 5, 'urban': 37, 'electro house': 63, 'acid jazz': 67, 'idm': 0, 'orchestral': 10, 'lounge': 57, 'Big Band': 0, 'bounce': 0, 'club': 29, 'funky': 43, 'remix': 20, 'breaks': 0, 'nu-jazz': 1, 'old school': 3, 'investigate': 0, 'Jazz Rock': 2, 'modern funk': 1, 'Soulful house': 0, 'grammy': 6, 'DIsco House': 0, 'harmonies': 2, 'Neo-Soul': 3, 'mod': 38, 'Old School soul': 8, 'funky house': 0, 'EDM': 0, 'america': 2, 'grammy winner': 152, 'Myjukebox': 75, 'disco music': 5, '70s Show': 3, 'hustle': 0, "70's": 48, 'Soul Funk': 0, 'disco-funk': 0, 'old school dance': 6, 'BANDA': 1, 'aint it funky': 0, 'GTA': 0, 'gta sa': 0, 'afterdark': 0, 'paradise garage': 0, 'philedelphia': 0, 'rare grooves': 0, 'gamble and huff': 0, 'The Loft': 0, 'nu-bluz': 1, 'Silky Sexy Smooth': 0, 'bounce fm': 0, 'funky stuff': 0, 'Alta-tensao': 0, 'electronic-lounge': 0, 'soulful dance': 0, 'favouritestreamableartists': 1, 'Estados Unidos': 0, 'grammy nominee': 12, 'instrumental soul': 0, 'Disco artists': 3, 'Nu-Bluz Funky Grooves in the E-Lounge': 0, 'DJSamPick': 0, 'progressive rock': 279, 'folk rock': 261, 'art rock': 249, 'psychedelic pop': 210, 'symphonic prog': 56, 'progressive pop': 130, 'folk': 493, 'country rock': 308, 'Progressive rock': 24, 'Symphonic Rock': 0, 'Classical': 26, 'Progressive': 19, 'Fusion': 26, 'eclectic prog': 0, 'symphonic': 0, 'classical music': 2, 'dutch prog': 0, 'classical themes': 0, 'prog': 0, 'Hammond': 23, 'prog rock': 0, 'netherlands': 22, 'the netherlands': 47, '70s pro ...

# %%
data = {'sig':audio_data_arr,
'tags':audio_tags_arr,
'artist':audio_artist_arr}


np.save('midi_2_channel_'+ str(len(audio_data_arr)) +'__' + genre_to_be_extracted + '__song_tags_artists.npy', data)

# %%
print(data['tags'])
# Out:
# [['rock', 'pop', 'blues', 'hard rock', 'blues rock', 'jazz fusion', 'christian rock', 'electric blues', 'blues-rock', 'aor', 'rock & roll'], ['rock', 'hard rock', 'soul', 'rhythm and blues', 'blues-rock'], ['pop', 'dutch', 'seen live', 'cover', 'Hip-Hop', 'hip hop', 'soul', 'rap', 'female vocalists', 'catchy', 'american', 'hiphop', 'rnb', 'live gezien', 'pur', 'ned', 'Less than 30000'], ['pop', 'dutch', 'seen live', 'cover', 'Hip-Hop', 'hip hop', 'soul', 'rap', 'female vocalists', 'catchy', 'american', 'hiphop', 'rnb', 'live gezien', 'pur', 'ned', 'Less than 30000'], ['pop', 'dutch', 'seen live', 'cover', 'Hip-Hop', 'hip hop', 'soul', 'rap', 'female vocalists', 'catchy', 'american', 'hiphop', 'rnb', 'live gezien', 'pur', 'ned', 'Less than 30000'], ['pop', 'dutch', 'seen live', 'cover', 'Hip-Hop', 'hip hop', 'soul', 'rap', 'female vocalists', 'catchy', 'american', 'hiphop', 'rnb', 'live gezien', 'pur', 'ned', 'Less than 30000'], ['rock', 'electronic', 'synthpop', 'pop', 'alternative rock', '70s', '80s', '90s', 'dance', 'british', 'new wave', 'electro', 'uk', 'pop rock', 'new romantic', 'english', '00s', 'classic pop and rock', 'male vocalists', '10s', 'new romantics'], ['rock', 'electronic', 'synthpop', 'pop', 'alternative rock', '70s', '80s', '90s', 'dance', 'british', 'new wave', 'electro', 'uk', 'pop rock', 'new romantic', 'english', '00s', 'classic pop and rock', 'male vocalists', '10s', 'new romantics'], ['rock', 'electronic', 'synthpop', 'pop', 'alternative rock', '70s', '80s', '90s', 'dance', 'british', 'new wave', 'electro', 'uk', 'pop rock', 'new romantic', 'english', '00s', 'classic pop and rock', 'male vocalists', '10s', 'new romantics'], ['rock', 'electronic', 'synthpop', 'pop', 'alternative rock', '70s', '80s', '90s', 'dance', 'british', 'new wave', 'electro', 'uk', 'pop rock', 'new romantic', 'english', '00s', 'classic pop and rock', 'male vocalists', '10s', 'new romantics'], ['rock', 'electronic', 'synthpop', 'pop', 'alternative rock', '70s', '80s', '90s', 'dance', 'british', 'new wave', 'electro', 'uk', 'pop rock', 'new romantic', 'english', '00s', 'classic pop and rock', 'male vocalists', '10s', 'new romantics'], ['rock', 'electronic', 'synthpop', 'pop', 'alternative rock', '70s', '80s', '90s', 'dance', 'british', 'new wave', 'electro', 'uk', 'pop rock', 'new romantic', 'english', '00s', 'classic pop and rock', 'male vocalists', '10s', 'new romantics'], ['rock', 'electronic', 'synthpop', 'pop', 'alternative rock', '70s', '80s', '90s', 'dance', 'british', 'new wave', 'electro', 'uk', 'pop rock', 'new romantic', 'english', '00s', 'classic pop and rock', 'male vocalists', '10s', 'new romantics'], ['rock', 'electronic', 'synthpop', 'pop', 'alternative rock', '70s', '80s', '90s', 'dance', 'british', 'new wave', 'electro', 'uk', 'pop rock', 'new romantic', 'english', '00s', 'classic pop and rock', 'male vocalists', '10s', 'new romantics'], ['rock', 'electronic', 'synthpop', 'pop', 'alternative rock', '70s', '80s', '90s', 'dance', 'british', 'new wave', 'electro', 'uk', 'pop rock', 'new romantic', 'english', '00s', 'classic pop and rock', 'male vocalists', '10s', 'new romantics'], ['rock', 'electronic', 'synthpop', 'pop', 'alternative rock', '70s', '80s', '90s', 'dance', 'british', 'new wave', 'electro', 'uk', 'pop rock', 'new romantic', 'english', '00s', 'classic pop and rock', 'male vocalists', '10s', 'new romantics'], ['rock', 'electronic', 'synthpop', 'pop', 'alternative rock', '70s', '80s', '90s', 'dance', 'british', 'new wave', 'electro', 'uk', 'pop rock', 'new romantic', 'english', '00s', 'classic pop and rock', 'male vocalists', '10s', 'new romantics'], ['rock', 'electronic', 'synthpop', 'pop', 'alternative rock', '70s', '80s', '90s', 'dance', 'british', 'new wave', 'electro', 'uk', 'pop rock', 'new romantic', 'english', '00s', 'classic pop and rock', 'male vocalists', '10s', 'new romantics'], ['rock', 'electronic', 'synthpop', 'pop', 'alternative rock', '70s', '80s', '90s', 'dance', 'british', 'new wave', 'el ...

# %%
npy_loc = 'midi_single_channel_7501__ALL__song_tags_artists.npy'
# npy_loc = '/kaggle/input/midi-numpy-array/midi_single_channel_2500__pop__song_tags_artists.npy'

data = np.load(npy_loc,allow_pickle=True)

x_audio_data_arr = data.item().get('sig') 
x_audio_tag_arr = data.item().get('tags')
x_audio_artist_arr = data.item().get('artist')

# %%
x_audio_data_arr = x_audio_data_arr[1000:3500]
x_audio_tag_arr = x_audio_tag_arr[1000:3500]
x_audio_artist_arr = x_audio_artist_arr[1000:3500]

# %%
data = {'sig':x_audio_data_arr,
'tags':x_audio_tag_arr,
'artist':x_audio_artist_arr}

np.save('midi_single_channel_2501__ALL__song_tags_artists.npy', data)

# %% [markdown]
# # EMOPIA PARSER

# %%
ARTIST_DIR = 'EMOPIA_1.0/EMOPIA_1.0/midis'

import os

audio_data_arr = []
audio_qs_arr = []

songs_to_be_extracted = 1555
genre_to_be_extracted = "blues" # 'ALL' # 'disco' # 'trance' # 'jazz'
disable_genre = False


df = pd.read_csv(r'artists_filtered.csv')

for dirname, _, filenames in os.walk(ARTIST_DIR):
    for filename in filenames:
        try:
            q = filename.split('_')[0]
            _rest = filename.split('_')[-1]
            name = filename.split('_' + _rest)[0].split(q + "_")[1]
            
            q = int(q[1])

            if '.mid' in filename:
                filepath = os.path.join(dirname, filename)

                audio_dict = Read_midi(filepath, 4).read_file()
                audio_matrix = dict_to_matrix(audio_dict)

#                 if len(audio_matrix) < 2:
#                     continue

                audio_data_arr.append(audio_matrix)
                audio_qs_arr.append(q)

                print('-->',len(audio_data_arr),'<--', len(audio_matrix), end="\r")
        except Exception as err:
            print("ERROR", err)
            pass

print('')

print(len(audio_data_arr))
print(len(audio_qs_arr))
# print(len(audio_artist_arr))
# audio_data_arr1 = audio_data_arr
# Out:
# --> 1078 <-- 1
# 1078
# 1078

# %%
data = {
    'sig':audio_data_arr,
    'q':audio_qs_arr
}


np.save('EMOPIA_'+ str(len(audio_data_arr)) + '__song_quads.npy', data)

# %% [markdown]
# # -- EMPOIA PARSER

# %% [markdown]
# ## Metadata Extractor

# %% [markdown]
# This is used to assign a genre from the dataset

# %%
import pandas as pd

df = pd.read_csv(r'LakhMIDI/artists.csv')

print(df)

# %%
found = 0
notfound = 0

dfCopy = df.copy(deep=True)
dfCopy = dfCopy[0:0]

display(dfCopy)

for dirname, _, filenames in os.walk('LakhMIDI/'):
#     for filename in filenames[:1]:
    if True:
        artist = dirname.split('LakhMIDI/')[1].replace('_', ' ')
        print(artist)
        if len(artist) < 2:
            continue
            
        entry = df[df['artist_mb'].str.contains(artist) == True] 
        IDs = entry.index.values
#         print(IDs)

        if len(entry) > 0 and len(entry) < 5:
            if len(entry) > 1:
                entry_new = df[(df['artist_mb'] == artist) == True]
                if len(entry_new) == 1:
                    entry = entry_new
                else:
                    entry = entry.sort_values(by=['listeners_lastfm', 'scrobbles_lastfm'], ascending=False)[0:1]
                    
            dfCopy = pd.concat([dfCopy,entry])
            display(dfCopy)
            found += 1
        else:
            notfound += 1

print("Found ", found)
print("Not Found ", notfound)

# %%
dfCopy.to_csv('artists_filtered.csv', index=False)

# %%
display(dfCopy)

# %%
print("Found ", found)
print("Not Found ", notfound)
# Out:
# Found  20
# Not Found  0

# %% [markdown]
# ## -- End of Metadata Extractor
